# %%
import random
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import itertools
import time

# %%
def plot_graph(graph, colors):
    G = nx.Graph(graph)
    node_colors = []
    for node in G.nodes():
        try:
            node_colors.append(colors[node])
        except KeyError:
            print("Čvor", node, "nema dodeljenu boju.")
            node_colors.append('gray')  # Postavljamo sivu boju za čvorove bez dodeljene boje
    nx.draw(G, with_labels=True, node_color=node_colors, cmap=plt.cm.rainbow, node_size=500)
    plt.show()


def read_graph_from_file(file_path):
    graph = nx.Graph()
    with open(file_path, 'r') as file:
        for line in file:
            parts = line.split()
            if parts[0] == 'e':
                graph.add_edge(int(parts[1]), int(parts[2]))
    return graph

def brute_force(graph):
    colors = {}  # Map to track assigned colors to nodes
    available_colors = set()  # Set of available colors
    
    # Initializing available colors
    for color in range(1, len(graph) + 1):
        available_colors.add(color)
    
    # Iterating through all nodes of the graph
    for node in graph:
        # Set of colors assigned to neighboring nodes
        neighbor_colors = {colors[neighbor] for neighbor in graph[node] if neighbor in colors}
        
        # Finding the first available color
        for color in available_colors:
            if color not in neighbor_colors:
                break
        
        # Assigning color to the node
        colors[node] = color
    
    # Calculating the total number of colors used
    num_colors = len(set(colors.values()))
    
    # Returning colors assigned to nodes and the total number of colors used
    return colors, num_colors

# %%
graph = {
    'A': ['B', 'C'],
    'B': ['A', 'C', 'D'],
    'C': ['A', 'B', 'D'],
    'D': ['B', 'C']
}

colors, num_colors = brute_force(graph)

print("Minimalan broj boja:", num_colors)

# Iscrtavanje grafa sa najboljim bojenjem
plot_graph(graph, colors)
# Out:
# Minimalan broj boja: 3

# %%
graph = {
    'A': ['B', 'C', 'D'],
    'B': ['A', 'C', 'D', 'E'],
    'C': ['A', 'B', 'D', 'F'],
    'D': ['A', 'B', 'C', 'E', 'F'],
    'E': ['B', 'D', 'G'],
    'F': ['C', 'D', 'H', 'I'],
    'G': ['E', 'J'],
    'H': ['F', 'I'],
    'I': ['F', 'H'],
    'J': ['G']
}
colors, num_colors = brute_force(graph)

print("Minimalan broj boja:", num_colors)

# Iscrtavanje grafa sa najboljim bojenjem
plot_graph(graph, colors)
# Out:
# Minimalan broj boja: 4

# %%
graph = read_graph_from_file('../File/fajl2.txt')  # Putanja do datoteke
colors, num_colors = brute_force(graph)

print("Minimalan broj boja:", num_colors)

# Iscrtavanje grafa sa najboljim bojenjem
plot_graph(graph, colors)
# Out:
# Minimalan broj boja: 31

# %%
graph = read_graph_from_file('../File/myciel7.txt')  # Putanja do datoteke
colors, num_colors = brute_force(graph)

print("Minimalan broj boja:", num_colors)

# Iscrtavanje grafa sa najboljim bojenjem
plot_graph(graph, colors)
# Out:
# Minimalan broj boja: 8

# %%
graph = read_graph_from_file('../File/games120.txt')  # Putanja do datoteke
colors, num_colors = brute_force(graph)

print("Minimalan broj boja:", num_colors)

# Iscrtavanje grafa sa najboljim bojenjem
plot_graph(graph, colors)

# %%
graph = nx.complete_graph(30)
colors, num_colors = brute_force(graph)

print("Minimalan broj boja:", num_colors)

# Iscrtavanje grafa sa najboljim bojenjem
plot_graph(graph, colors)
