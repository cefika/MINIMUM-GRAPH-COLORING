# %%
import random
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import itertools
import time

# %%
import networkx as nx
from itertools import product
import time

def brute_force_node_coloring(graph, start_time):
    n = len(graph.nodes())
    iters = 0

    for coloring in product(range(1, n + 1), repeat=n):
        iters += 1
        if time.time() - start_time >= 300:
            return -1, -1
        if is_valid_node_coloring(graph, coloring):
            return {node: coloring[i] for i, node in enumerate(graph.nodes())}, iters
            
    return None, iters

def is_valid_node_coloring(graph, coloring):
    node_color = {node: coloring[i] for i, node in enumerate(graph.nodes())}
    
    for node in graph.nodes():
        for neighbor in graph.neighbors(node):
            if node_color[node] == node_color[neighbor]:
                return False
    return True

def plot_graph(graph, colors):
    G = nx.Graph(graph)
    node_colors = []
    for node in G.nodes():
        try:
            node_colors.append(colors[node])
        except KeyError:
            print("Čvor", node, "nema dodeljenu boju.")
            node_colors.append('gray')  # Postavljamo sivu boju za čvorove bez dodeljene boje
    nx.draw(G, with_labels=True, node_color=node_colors, cmap=plt.cm.rainbow, node_size=500)
    plt.show()

def read_graph_from_file(file_path):
    graph = nx.Graph()
    with open(file_path, 'r') as file:
        for line in file:
            parts = line.split()
            if parts[0] == 'e':
                graph.add_edge(int(parts[1]), int(parts[2]))
    return graph


def format_time(seconds):
    return "{:.10f}".format(seconds)

# %%
def appendToFile(filename,num_colors_used,elapsed_time):
    podaci.append(filename+".txt")
    podaci.append("Broj boja: "+str(num_colors_used))
    podaci.append("Vreme: "+format_time(elapsed_time)+"sekundi")

    
    with open("../Rezultati/brute_force.txt", "a") as fajl:
        for podatak in podaci:
                fajl.write(f"{podatak}\n")

    podaci.clear()

# %%
graph = {
    'A': ['B', 'C'],
    'B': ['A', 'C', 'D'],
    'C': ['A', 'B', 'D'],
    'D': ['B', 'C']
}

G = nx.Graph(graph)

start_time = time.time()
colors, iters = brute_force_node_coloring(G, start_time)
end_time = time.time()

if colors == -1:
    print("Premašeno vreme od 300 sekundi.")
else:
    print("Minimalan broj boja:", len(set(colors.values())))
    print("Boje čvorova:", colors)
    print("Broj iteracija:", iters)
    print("Vreme izvršavanja za test primer:", format_time(end_time - start_time), "sekundi")

plot_graph(G, colors)
# Out:
# Minimalan broj boja: 3
# Boje čvorova: {'A': 1, 'B': 2, 'C': 3, 'D': 1}
# Broj iteracija: 25
# Vreme izvršavanja za test primer: 0.0002758503 sekundi

# %%
podaci=[]
podaci.append("small_1")
podaci.append("Broj boja: "+str(len(set(colors.values()))))
podaci.append("Vreme: "+str(format_time(end_time - start_time))+"sekundi")

with open("../Rezultati/brute_force.txt", "w") as fajl:
    for podatak in podaci:
            fajl.write(f"{podatak}\n")
podaci.clear()

# %%
#small 2
graph = {
    'A': ['B', 'C', 'D'],
    'B': ['A', 'C', 'D', 'E'],
    'C': ['A', 'B', 'D', 'F'],
    'D': ['A', 'B', 'C', 'E', 'F'],
    'E': ['B', 'D', 'G'],
    'F': ['C', 'D', 'H', 'I'],
    'G': ['E', 'J'],
    'H': ['F', 'I'],
    'I': ['F', 'H'],
    'J': ['G']
}

G = nx.Graph(graph)

start_time = time.time()
colors, iters = brute_force_node_coloring(G, start_time)
end_time = time.time()

if colors == -1:
    print("Premašeno vreme od 300 sekundi.")
    appendToFile("small_2", 0, 300)
else:
    print("Minimalan broj boja:", len(set(colors.values())))
    print("Boje čvorova:", colors)
    print("Broj iteracija:", iters)

    print("Vreme izvršavanja za test primer:", format_time(end_time - start_time), " sekundi")

    appendToFile("small_2", len(set(colors.values())), format_time(end_time - start_time))

    plot_graph(G, colors)
# Out:
# Premašeno vreme od 300 sekundi.

# %%
#small 3
graph = {
    'A': ['B', 'C', 'D'],
    'B': ['A', 'C', 'D'],
    'C': ['A', 'B', 'D', 'E'],
    'D': ['A', 'B', 'C', 'E'],
    'E': ['C', 'D']
}

# %%
G = nx.Graph(graph)

start_time = time.time()
colors, iters = brute_force_node_coloring(G, start_time)
end_time = time.time()

if colors == -1:
    print("Premašeno vreme od 300 sekundi.")
    appendToFile("small_3", 0, 300)
else:
    print("Minimalan broj boja:", len(set(colors.values())))
    print("Boje čvorova:", colors)
    print("Broj iteracija:", iters)

    print("Vreme izvršavanja za test primer:", format_time(end_time - start_time), " sekundi")

    appendToFile("small_3", len(set(colors.values())),(end_time - start_time))

    plot_graph(G, colors)
# Out:
# Minimalan broj boja: 4
# Boje čvorova: {'A': 1, 'B': 2, 'C': 3, 'D': 4, 'E': 1}
# Broj iteracija: 191
# Vreme izvršavanja za test primer: 0.0005247593  sekundi

# %%
#small 4
graph = {
    'A' : ['B', 'C'],
    'B' : ['D', 'E'],
    'C' : ['A', 'B'],
    'D' : ['B'],
    'E' : ['B']
}

# %%
G = nx.Graph(graph)

start_time = time.time()
colors, iters = brute_force_node_coloring(G, start_time)
end_time = time.time()

if colors == -1:
    print("Premašeno vreme od 300 sekundi.")
    appendToFile("small_4", 0, 300)
else:
    print("Minimalan broj boja:", len(set(colors.values())))
    print("Boje čvorova:", colors)
    print("Broj iteracija:", iters)

    print("Vreme izvršavanja za test primer:", format_time(end_time - start_time), " sekundi")

    appendToFile("small_4", len(set(colors.values())), (end_time - start_time))

    plot_graph(G, colors)
# Out:
# Minimalan broj boja: 3
# Boje čvorova: {'A': 1, 'B': 2, 'C': 3, 'D': 1, 'E': 1}
# Broj iteracija: 176
# Vreme izvršavanja za test primer: 0.0007140636  sekundi

# %%
#small 5
graph = {
    'A': ['B', 'C', 'D'],
    'B': ['A', 'D'],
    'C': ['A', 'E', 'G'],
    'D': ['A', 'B', 'F', 'G'],
    'E': ['C'],
    'F': ['D', 'G'],
    'G': ['C', 'D', 'F']
}

# %%
G = nx.Graph(graph)

start_time = time.time()
colors, iters = brute_force_node_coloring(G, start_time)
end_time = time.time()

if colors == -1:
    print("Premašeno vreme od 300 sekundi.")
    appendToFile("small_5", 0, 300)
else:
    print("Minimalan broj boja:", len(set(colors.values())))
    print("Boje čvorova:", colors)
    print("Broj iteracija:", iters)

    print("Vreme izvršavanja za test primer:", format_time(end_time - start_time), " sekundi")

    appendToFile("small_5", len(set(colors.values())), (end_time - start_time))

    plot_graph(G, colors)
# Out:
# Minimalan broj boja: 4
# Boje čvorova: {'A': 1, 'B': 2, 'C': 2, 'D': 3, 'E': 1, 'F': 1, 'G': 4}
# Broj iteracija: 19898
# Vreme izvršavanja za test primer: 0.0254795551  sekundi

# %%
#small 6
graph = {
    'A': ['B', 'F', 'D', 'E'],
    'B': ['A', 'C', 'E', 'F'],
    'C': ['B', 'D', 'F', 'A'],
    'D': ['C', 'E', 'A', 'B'],
    'E': ['D', 'F', 'B', 'C'],
    'F': ['E', 'A', 'C', 'D']
}

# %%
G = nx.Graph(graph)

start_time = time.time()
colors, iters = brute_force_node_coloring(G, start_time)
end_time = time.time()

if colors == -1:
    print("Premašeno vreme od 300 sekundi.")
    appendToFile("small_6", 0, 300)
else:
    print("Minimalan broj boja:", len(set(colors.values())))
    print("Boje čvorova:", colors)
    print("Broj iteracija:", iters)

    print("Vreme izvršavanja za test primer:", format_time(end_time - start_time), " sekundi")

    appendToFile("small_6", len(set(colors.values())), (end_time - start_time))

    plot_graph(G, colors)
# Out:
# Minimalan broj boja: 6
# Boje čvorova: {'A': 1, 'B': 2, 'C': 3, 'D': 4, 'E': 5, 'F': 6}
# Broj iteracija: 1866
# Vreme izvršavanja za test primer: 0.0042202473  sekundi

# %%
graph = read_graph_from_file('../File/fajl2.txt')

G = nx.Graph(graph)

start_time = time.time()
colors, num_colors = brute_force_node_coloring(graph,start_time)
end_time = time.time()

if colors == -1:
    print("Premašeno vreme od 300 sekundi.")
    appendToFile("fajl2", 0, 300)
else:
    print("Minimalan broj boja:", len(set(colors.values())))
    print("Boje čvorova:", colors)
    print("Broj iteracija:", iters)

    print("Vreme izvršavanja za test primer:", format_time(end_time - start_time), "sekundi")
    appendToFile("fajl2", len(set(colors.values())), (end_time - start_time))

    plot_graph(graph, colors)
# Out:
# Premašeno vreme od 300 sekundi.

# %%
graph = read_graph_from_file('../File/myciel7.txt')  # Putanja do datoteke
G = nx.Graph(graph)

start_time = time.time()
colors, num_colors = brute_force_node_coloring(graph,start_time)
end_time = time.time()

if colors == -1:
    print("Premašeno vreme od 300 sekundi.")
    appendToFile("myciel7", 0, 300)
else:
    print("Minimalan broj boja:", len(set(colors.values())))
    print("Boje čvorova:", colors)
    print("Broj iteracija:", iters)

    print("Vreme izvršavanja za test primer:", format_time(end_time - start_time), "sekundi")
    appendToFile("myciel7", len(set(colors.values())), (end_time - start_time))

    plot_graph(graph, colors)
# Out:
# Premašeno vreme od 300 sekundi.

# %%
graph = read_graph_from_file('../File/games120.txt') 
G = nx.Graph(graph)

start_time = time.time()
colors, num_colors = brute_force_node_coloring(graph,start_time)
end_time = time.time()

if colors == -1:
    print("Premašeno vreme od 300 sekundi.")
    appendToFile("games120", 0, 300)
else:
    print("Minimalan broj boja:", len(set(colors.values())))
    print("Boje čvorova:", colors)
    print("Broj iteracija:", iters)

    print("Vreme izvršavanja za test primer:", format_time(end_time - start_time), "sekundi")
    appendToFile("games120", len(set(colors.values())), (end_time - start_time))

    plot_graph(graph, colors)
# Out:
# Premašeno vreme od 300 sekundi.

# %%
graph = nx.complete_graph(30)
G = nx.Graph(graph)

start_time = time.time()
colors, num_colors = brute_force_node_coloring(graph,start_time)
end_time = time.time()

if colors == -1:
    print("Premašeno vreme od 300 sekundi.")
    appendToFile("kompletan_graf", 0, 300)
else:
    print("Minimalan broj boja:", len(set(colors.values())))
    print("Boje čvorova:", colors)
    print("Broj iteracija:", iters)

    print("Vreme izvršavanja za test primer:", format_time(end_time - start_time), "sekundi")
    appendToFile("kompletan graf", len(set(colors.values())), (end_time - start_time))

    plot_graph(graph, colors)
# Out:
# Premašeno vreme od 300 sekundi.

# %%
graph = read_graph_from_file('../File/test1.txt')  # Putanja do datoteke
G = nx.Graph(graph)

start_time = time.time()
colors, num_colors = brute_force_node_coloring(graph,start_time)
end_time = time.time()

if colors == -1:
    print("Premašeno vreme od 300 sekundi.")
    appendToFile("test1", 0, 300)
else:
    print("Minimalan broj boja:", len(set(colors.values())))
    print("Boje čvorova:", colors)
    print("Broj iteracija:", iters)

    print("Vreme izvršavanja za test primer:", format_time(end_time - start_time), "sekundi")
    appendToFile("test1", len(set(colors.values())), (end_time - start_time))

    plot_graph(graph, colors)
# Out:
# Premašeno vreme od 300 sekundi.

# %%
graph = read_graph_from_file('../File/test2.txt')  # Putanja do datoteke
G = nx.Graph(graph)

start_time = time.time()
colors, num_colors = brute_force_node_coloring(graph,start_time)
end_time = time.time()

if colors == -1:
    print("Premašeno vreme od 300 sekundi.")
    appendToFile("test2", 0, 300)
else:
    print("Minimalan broj boja:", len(set(colors.values())))
    print("Boje čvorova:", colors)
    print("Broj iteracija:", iters)

    print("Vreme izvršavanja za test primer:", format_time(end_time - start_time), "sekundi")
    appendToFile("test2", len(set(colors.values())), (end_time - start_time))

    plot_graph(graph, colors)
# Out:
# Premašeno vreme od 300 sekundi.

# %%
graph = read_graph_from_file('../File/test4.txt')  # Putanja do datoteke
G = nx.Graph(graph)

start_time = time.time()
colors, num_colors = brute_force_node_coloring(graph,start_time)
end_time = time.time()

if colors == -1:
    print("Premašeno vreme od 300 sekundi.")
    appendToFile("test4", 0, 300)
else:
    print("Minimalan broj boja:", len(set(colors.values())))
    print("Boje čvorova:", colors)
    print("Broj iteracija:", iters)

    print("Vreme izvršavanja za test primer:", format_time(end_time - start_time), "sekundi")
    appendToFile("test4", len(set(colors.values())), (end_time - start_time))

    plot_graph(graph, colors)
# Out:
# Premašeno vreme od 300 sekundi.
