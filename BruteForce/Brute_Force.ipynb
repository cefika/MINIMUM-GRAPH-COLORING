# %%
import random
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import itertools
import time

# %%
import networkx as nx
from itertools import product
import time

def brute_force_node_coloring(graph, start_time):
    n = len(graph.nodes())
    iters = 0

    for coloring in product(range(1, n + 1), repeat=n):
        iters += 1
        if time.time() - start_time >= 300:
            return -1, -1
        if is_valid_node_coloring(graph, coloring):
            return {node: coloring[i] for i, node in enumerate(graph.nodes())}, iters
            
    return None, iters

def is_valid_node_coloring(graph, coloring):
    node_color = {node: coloring[i] for i, node in enumerate(graph.nodes())}
    
    for node in graph.nodes():
        for neighbor in graph.neighbors(node):
            if node_color[node] == node_color[neighbor]:
                return False
    return True

def plot_graph(graph, colors):
    G = nx.Graph(graph)
    node_colors = []
    for node in G.nodes():
        try:
            node_colors.append(colors[node])
        except KeyError:
            print("Čvor", node, "nema dodeljenu boju.")
            node_colors.append('gray')  # Postavljamo sivu boju za čvorove bez dodeljene boje
    nx.draw(G, with_labels=True, node_color=node_colors, cmap=plt.cm.rainbow, node_size=500)
    plt.show()

def read_graph_from_file(file_path):
    graph = nx.Graph()
    with open(file_path, 'r') as file:
        for line in file:
            parts = line.split()
            if parts[0] == 'e':
                graph.add_edge(int(parts[1]), int(parts[2]))
    return graph


def format_time(seconds):
    return "{:.10f}".format(seconds)

# %%
# Primer graf kao rečnik
graph = {
    'A': ['B', 'C'],
    'B': ['A', 'C', 'D'],
    'C': ['A', 'B', 'D'],
    'D': ['B', 'C']
}

# Konvertovanje u networkx graf
G = nx.Graph(graph)

start_time = time.time()
colors, iters = brute_force_node_coloring(G, start_time)
end_time = time.time()

if colors == -1:
    print("Premašeno vreme od 300 sekundi.")
else:
    print("Minimalan broj boja:", len(set(colors.values())))
    print("Boje čvorova:", colors)
    print("Broj iteracija:", iters)
    print("Vreme izvršavanja za test primer:", format_time(end_time - start_time), "sekundi")


    # Iscrtavanje grafa sa najboljim bojenjem
    plot_graph(G, colors)
# Out:
# Minimalan broj boja: 3
# Boje čvorova: {'A': 1, 'B': 2, 'C': 3, 'D': 1}
# Broj iteracija: 25
# Vreme izvršavanja za test primer: 0.0002181530 sekundi

# %%
graph = {
    'A': ['B', 'C', 'D'],
    'B': ['A', 'C', 'D', 'E'],
    'C': ['A', 'B', 'D', 'F'],
    'D': ['A', 'B', 'C', 'E', 'F'],
    'E': ['B', 'D', 'G'],
    'F': ['C', 'D', 'H', 'I'],
    'G': ['E', 'J'],
    'H': ['F', 'I'],
    'I': ['F', 'H'],
    'J': ['G']
}

# Konvertovanje u networkx graf
G = nx.Graph(graph)

start_time = time.time()
colors, iters = brute_force_node_coloring(G, start_time)
end_time = time.time()

if colors == -1:
    print("Premašeno vreme od 150 sekundi.")
else:
    print("Minimalan broj boja:", len(set(colors.values())))
    print("Boje čvorova:", colors)
    print("Broj iteracija:", iters)

    print("Vreme izvršavanja za test primer:", format_time(end_time - start_time), "sekundi")
    # Iscrtavanje grafa sa najboljim bojenjem
    plot_graph(G, colors)
# Out:
# Minimalan broj boja: 4
# Boje čvorova: {'A': 1, 'B': 2, 'C': 3, 'D': 4, 'E': 1, 'F': 1, 'G': 2, 'H': 2, 'I': 3, 'J': 1}
# Broj iteracija: 123001121
# Vreme izvršavanja za test primer: 218.3679385185 sekundi

# %%
graph = read_graph_from_file('../File/fajl2.txt')  # Putanja do datoteke

start_time = time.time()
colors, num_colors = brute_force_node_coloring(graph,start_time)
end_time = time.time()

if colors == -1:
    print("Premašeno vreme od 300 sekundi.")
else:
    print("Minimalan broj boja:", len(set(colors.values())))
    print("Boje čvorova:", colors)
    print("Broj iteracija:", iters)

    print("Vreme izvršavanja za test primer:", format_time(end_time - start_time), "sekundi")
    # Iscrtavanje grafa sa najboljim bojenjem
    plot_graph(graph, colors)
# Out:
# Premašeno vreme od 150 sekundi.

# %%
graph = read_graph_from_file('../File/myciel7.txt')  # Putanja do datoteke
start_time = time.time()
colors, num_colors = brute_force_node_coloring(graph,start_time)
end_time = time.time()

if colors == -1:
    print("Premašeno vreme od 300 sekundi.")
else:
    print("Minimalan broj boja:", len(set(colors.values())))
    print("Boje čvorova:", colors)
    print("Broj iteracija:", iters)

    print("Vreme izvršavanja za test primer:", format_time(end_time - start_time), "sekundi")
    # Iscrtavanje grafa sa najboljim bojenjem
    plot_graph(graph, colors)
# Out:
# Premašeno vreme od 150 sekundi.

# %%
graph = read_graph_from_file('../File/games120.txt')  # Putanja do datoteke
start_time = time.time()
colors, num_colors = brute_force_node_coloring(graph,start_time)
end_time = time.time()

if colors == -1:
    print("Premašeno vreme od 300 sekundi.")
else:
    print("Minimalan broj boja:", len(set(colors.values())))
    print("Boje čvorova:", colors)
    print("Broj iteracija:", iters)

    print("Vreme izvršavanja za test primer:", format_time(end_time - start_time), "sekundi")
    # Iscrtavanje grafa sa najboljim bojenjem
    plot_graph(graph, colors)
# Out:
# Premašeno vreme od 300 sekundi.

# %%
graph = nx.complete_graph(30)
start_time = time.time()
colors, num_colors = brute_force_node_coloring(graph,start_time)
end_time = time.time()

if colors == -1:
    print("Premašeno vreme od 300 sekundi.")
else:
    print("Minimalan broj boja:", len(set(colors.values())))
    print("Boje čvorova:", colors)
    print("Broj iteracija:", iters)

    print("Vreme izvršavanja za test primer:", format_time(end_time - start_time), "sekundi")
    # Iscrtavanje grafa sa najboljim bojenjem
    plot_graph(graph, colors)
# Out:
# Premašeno vreme od 300 sekundi.
